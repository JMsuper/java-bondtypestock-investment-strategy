# %%
# !pip install opendartreader

# %%
import OpenDartReader

api_key = 'a581578fd2d6f0b97cabb5d91d448de4c8a3b4dd'

dart = OpenDartReader(api_key)

dart.list('005930')
# Out:
#      corp_code corp_name stock_code corp_cls              report_nm  \
# 0     00126380      삼성전자     005930        Y         최대주주등소유주식변동신고서
# 1     00126380      삼성전자     005930        Y           기타경영사항(자율공시)
# 2     00126380      삼성전자     005930        Y           기타경영사항(자율공시)
# 3     00126380      삼성전자     005930        Y           기타경영사항(자율공시)
# 4     00126380      삼성전자     005930        Y            특수관계인과의내부거래
# ...        ...       ...        ...      ...                    ...
# 5649  00126380      삼성전자     005930        Y           채무보증(담보제공포함)
# 5650  00126380      삼성전자     005930        Y          최대주주등을위한금전의대여
# 5651  00126380      삼성전자     005930        Y        감사보고서 (1999.12)
# 5652  00126380      삼성전자     005930        Y  [기재정정]반기보고서 (1999.06)
# 5653  00126380      삼성전자     005930        Y  [기재정정]사업보고서 (1998.12)
#
#             rcept_no  flr_nm  rcept_dt rm
# 0     20221206800277    삼성전자  20221206  유
# 1     20221201800184    삼성전자  20221201  유
# ...

# %%
dart.list('005930',start='1999-01-01',kind='A')
# Out:
#    corp_code corp_name stock_code corp_cls              report_nm  \
# 0   00126380      삼성전자     005930        Y        분기보고서 (2022.09)
# 1   00126380      삼성전자     005930        Y        반기보고서 (2022.06)
# 2   00126380      삼성전자     005930        Y        분기보고서 (2022.03)
# 3   00126380      삼성전자     005930        Y        사업보고서 (2021.12)
# 4   00126380      삼성전자     005930        Y        분기보고서 (2021.09)
# ..       ...       ...        ...      ...                    ...
# 89  00126380      삼성전자     005930        Y        반기보고서 (2000.06)
# 90  00126380      삼성전자     005930        Y  [첨부추가]사업보고서 (1999.12)
# 91  00126380      삼성전자     005930        Y        분기보고서 (2000.03)
# 92  00126380      삼성전자     005930        Y  [기재정정]반기보고서 (1999.06)
# 93  00126380      삼성전자     005930        Y  [기재정정]사업보고서 (1998.12)
#
#           rcept_no flr_nm  rcept_dt rm
# 0   20221114001832   삼성전자  20221114
# 1   20220816001711   삼성전자  20220816
# 2   20220516001751   삼성전자  20220516
# ...

# %%
ss_finstate = dart.finstate('삼성전자',2021)

# %%
net_income = ss_finstate[(ss_finstate['account_nm']=='당기순이익')&(ss_finstate['fs_nm']=='재무제표')]['frmtrm_amount']

# %%
net_income = int(net_income.to_list()[0].replace(',',''))

# %%
print(net_income)
# Out:
# 15615018000000

# %%
ss_finstate
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 1   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 2   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 3   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 4   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 5   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 6   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 7   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 8   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 9   20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# 10  20220308000798      11011      2021  00126380     005930    CFS  연결재무제표
# ...
