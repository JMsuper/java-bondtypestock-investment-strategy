# %%
import dart_fss as dart

api_key = 'a581578fd2d6f0b97cabb5d91d448de4c8a3b4dd'

dart.set_api_key(api_key=api_key)

# 삼성전자 기업코드 : '00126380'
# bgn_de : 검색시작날짜
# end_de : 검색종료날짜
# report_tp : 연간, 반기, 분기 보고서 중 선택
corp_code = '00126380'
Financial_Statements = dart.fs.extract(corp_code=corp_code, bgn_de='20211231', end_de='20220505', report_tp='annual')
# Out:
# Annual reports:   0%|          | 0/1 [00:00<?, ?report/s]

# %%
Income_Statement = Financial_Statements.show(tp='is')

# %%
Income_Statement.iloc[:,1:-2]
# Out:
#    [D310000] Income statement, by function of expense - Consolidated financial statements (Unit: KRW)  \
#                                                                                              label_ko
# 0                                             수익(매출액)
# 1                                                매출원가
# 2                                               매출총이익
# 3                                             판매비와관리비
# 4                                                영업이익
# 5                                                기타수익
# 6                                                기타비용
# 7                                               지분법이익
# 8                                                금융수익
# 9                                                금융비용
# 10                                    법인세비용차감전순이익(손실)
# 11                                              법인세비용
# 12                                         계속영업이익(손실)
# 13                                          당기순이익(손실)
# ...

# %%
# Income_Statement[Income_Statement['label_ko']=='당기순이익(손실)']
Income_Statement.columns
# Out:
# MultiIndex([('[D310000] Income statement, by function of expense - Consolidated financial statements (Unit: KRW)', ...),
#             ('[D310000] Income statement, by function of expense - Consolidated financial statements (Unit: KRW)', ...),
#             ('[D310000] Income statement, by function of expense - Consolidated financial statements (Unit: KRW)', ...),
#             ('[D310000] Income statement, by function of expense - Consolidated financial statements (Unit: KRW)', ...),
#             ('[D310000] Income statement, by function of expense - Consolidated financial statements (Unit: KRW)', ...),
#             ('[D310000] Income statement, by function of expense - Consolidated financial statements (Unit: KRW)', ...),
#             (                                                                                 '20210101-20211231', ...),
#             (                                                                                 '20200101-20201231', ...),
# ...
